# %%
# %cd /content/
# !rm -rf tts_on_colab
# !git clone https://github.com/pseudo-usama/tts-on-colab.git tts_on_colab

# %%
# %cd /content/tts_on_colab/

# !pip install -q -r tts_on_colab/requirements.txt
# !apt-get -qq -y install espeak-ng > /dev/null 2>&1

# %%
from api import start_server
start_server()

# !npx localtunnel --port 5000 --subdomain myttsserver

# %%
# Only for testing
# %cd /content/tts_on_colab/
from tts import make_audio_and_subtitles
from IPython.display import Audio, display

results = make_audio_and_subtitles(["Hi man"], voice="am_liam")
for wav, srt in results:
    display(Audio(wav))
